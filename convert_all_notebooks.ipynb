# %%
import os
import glob
import socket

if socket.gethostname() != 'apokalite':
    print('\n\nEnter the full path name of the root directory of the installation\nor\nPress \'Enter\' to indicate this file\'s present location')
    basedir=input()
    if basedir=='':
        basedir=os.getcwd()
else:
    basedir='/home/david/gh/intro_curve_fitting_python'
try:
    os.chdir(basedir)
except:
    print('problem changing to basedir; rerun this program. the kernel will now restart.')
    quit()

print(f'now in {basedir}\n')
# Out:
# now in /home/david/gh/intro_curve_fitting_python

# %%
nbs = glob.glob("*.ipynb")

# %%
for nb in nbs:
    command='jupyter nbconvert '+nb+' --to pdf'
    os.system(command)
# Out:
# [NbConvertApp] Converting notebook generate_datasets.ipynb to pdf
# [NbConvertApp] Support files will be in generate_datasets_files/
# [NbConvertApp] Making directory ./generate_datasets_files
# [NbConvertApp] Writing 49934 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 124755 bytes to generate_datasets.pdf
# [NbConvertApp] Converting notebook Houston.ipynb to pdf
# [NbConvertApp] Writing 21589 bytes to notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: ['xelatex', 'notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: ['bibtex', 'notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# ...
