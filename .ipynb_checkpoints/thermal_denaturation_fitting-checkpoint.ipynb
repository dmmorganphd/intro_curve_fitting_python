# %% [markdown]
# # Fitting thermal denaturation data
# ## Do imports

# %%
# %run -i 'imports.py'

# %%
# %run -i 'definitions_and_defaults.py'

# %% [markdown]
# The Brautigam laboratory's equation for fitting protein thermal denaturation data is:
# $$\frac{m_1*T+b_1+(m_2*T+b_2)*e^{-\frac{\Delta H}{RT}(1-\frac{T}{TM})}}{1+e^{-\frac{\Delta H}{RT}(1-\frac{T}{TM})}}$$<br>
# in which:
# | Symbol | Meaning     |
# | ------:| -----------:|
# | $T$ | absolute temperature, the independent variable
# | $\theta$   | arbitrary temperature-dependent signal reporting the denaturation $K_{eq}$  |
# | $m_1$ | slope of line in low-temperature region |
# | $b_1$ | intercept of line in low-temperature region |
# | $m_2$ | slope of line in high-temperature region |
# | $b_2$ | intercept of line in high-temperature region |
# | $\Delta H $ | denaturation enthalpy, units as per choice of $R$ |
# | $R$ | the gas constant, in whichever units are preferred |
# | $T_M$ | melting temperature, Kelvin |

# %% [markdown]
# This equation is an adaptation of the integrated form of the [van't Hoff equation](https://en.wikipedia.org/wiki/Van_%27t_Hoff_equation), and my own derivation of it may be found [here](./derivation.ipynb). The derivation clarifies that a a four-parameter result$^\dagger$ is 'on the way' to the six-parameter result above. In the notebook, I derive both, use each to treat a real data set, and apply an F-test to decide which provides the better fit.<br><br>$\dagger$: A sigmoidal equation of the form:$$f(x)=\frac{a+b*e^{-x}}{1+e^{-x}}$$
# of which the fitting equation is an elaboration.

# %% [markdown]
# ## Encode the fitting function:

# %%
# if the value of a variable is specified in the definition of a function,
# that is its default value, and the function may be called without specifying 
# that parameter or its value. if, when called, the value of the variable
# is specified, that value overrides the default

# define the function
# note then that the default units for deltaH are J/mol
def tdmodel(T, m1, b1, m2, b2, deltaH, TM, R=8.314):
    line1=m1*T+b1
    line2=m2*T+b2
    Q=np.exp(-deltaH/(R*T)*(1-T/TM))
    return (line1+line2*Q)/(1+Q)

# %% [markdown]
# ## Good initial estimates for fittable parameters
# Evidently this equation, which has 6 fittable parameters, is quite a bit more complicated than those necessary to fit linear and exponential decay data. With this number of variables, it's essential to have excellent initial parameter estimates. I walk through one example of how I accomplished that for a PupB NTSD mutant using actual Colbert Lab data. <br><br>
# In the '.../intro_curve_fitting_python/thermal_denaturation_data' directory, find the following files:

# %%
datadir = basedir+'/thermal_denaturation_data/'
os.listdir(datadir)
# Out:
# ['PupB NTSD L74A 25 uM 217 nm R.csv',
#  'PupB NTSD H72D 25 uM 217nm R.csv',
#  'PupB NTSD L74A 25 uM 217 nm F.csv',
#  'PupB NTSD Q69K 25 uM 217nm F.csv',
#  'PupB NTSD Q69K 25 uM 217nm R.csv',
#  'PupB NTSD H72D 25 uM 217nm F.csv',
#  'dmm_L74A_F_fit_figure.png',
#  'PupB NTSD L74A 25 uM 217 nm F.tsv']

# %% [markdown]
# ## An alternative means of reading csv files:
# See [here](https://docs.python.org/3/library/csv.html) for more.

# %%
import csv

fn = datadir+'PupB NTSD L74A 25 uM 217 nm F.csv'
csvfile = open(fn)
csvreader = csv.reader(csvfile, delimiter=',')

# create empty x and y arrays
x = []
y = []

for row in csvreader:
    x.append(float(row[0]))
    y.append(float(row[1]))

csvfile.close()

# make x and y proper np arrays
x = np.array(x)
y = np.array(y)

# %% [markdown]
# ## Scatter Plot:
# <i>Always</i> look at your raw data.

# %%
# scatter plot:
plt.scatter(x,y)
plt.show()

# %% [markdown]
# ## Get the low- and high-temperature lines:
# As you've seen now, linear fits are insanely easy, so it is straightforward to get good initial estimates for $m_1$, $b_1$, $m_2$, and $b_2$. Let's do that:

# %%
# get the first 20 points for a low temp line

# the following 'slices' the array x beginnning with the (implied)
# 0 prior to the colon, and ending with the 20 indicating the 
# first array element _not_ to include in the 'slice'
eks = x[:20]
why = y[:20]

ltlineparam, pcov = curve_fit(sl, eks, why)
m1 = ltlineparam[0]
b1 = ltlineparam[1]

# get the last 12 points for a high temp line

# more slicing syntax
# if the argument prior to the colon is negative, it means
# 'start counting from the end of the array'
# therefore, 'cut from the 12th from the last element of the 
# array through to the end'
eks = x[-12:]
why = y[-12:]

htlineparam, pcov = curve_fit(sl, eks, why)
m2 = htlineparam[0]
b2 = htlineparam[1]

# %% [markdown]
# ## Estimates for $\Delta H$ and $T_M$
#
# For $\Delta H$, because an order of magnitude guess is sufficient, let's go with 100 kJ / mol.<br>
# $T_M$ may be eye-balled from the curve, I make it 335 K.

# %%
deltaH = 100000
TM = 335
print('initial guesses for fitting:')
print('m1: %0.3f, b1: %0.3f, m2: %0.3f, b2: %0.3f, deltaH: %0.0f, TM: %0.0f' % (m1, b1, m2, b2, deltaH, TM))
# Out:
# initial guesses for fitting:
# m1: 0.025, b1: -19.107, m2: 0.032, b2: -18.782, deltaH: 100000, TM: 335

# %% [markdown]
# ## Compare Initial Paramters Against Data:

# %%
mintemp = 4 # degrees C
maxtemp = 104
mintemp += 273.15 # conversion to Kelvin
maxtemp += 273.15
eks = np.linspace(mintemp, maxtemp, 15)

sigma = tdmodel(eks, m1, b1, m2, b2, deltaH, TM)
plt.plot(eks,sigma, 'k-')
plt.scatter(x,y)
plt.show()

# %% [markdown]
# Yes, that is close enough.
# ## Do the fitting
# using the values just estimated as initial guesses:

# %%
p = [m1, b1, m2, b2, deltaH, TM]

# do it
# argument 'p0=p' supplies initial guesses for fittable parameters
popt, pcov = curve_fit(tdmodel, x, y, p0=p) 
popt
# Out:
# array([ 2.85739746e-02, -2.00378479e+01, -6.32331433e-02,  1.37202477e+01,
#         2.85627011e+05,  3.29470759e+02])

# %% [markdown]
# ## Compute residuals and R$^2$:

# %%
residuals = y - tdmodel(x, *popt)
rsq = rsqrd(residuals, y)
print('Rsquared: %0.3f' % rsq)
# Out:
# Rsquared: 0.981

# %% [markdown]
# ## Prepare a figure:

# %%
fn = basedir+'/thermal_denaturation_data/dmm_L74A_F_fit_figure.png'
eks = np.linspace(np.min(x), np.max(x), 100)
why = tdmodel(eks, *popt)

# create a figure
fig = plt.figure()
fig.set_figwidth=(6)
fig.set_figheight(6)

# create grid for different subplots
spec = gridspec.GridSpec(ncols=1, nrows=2,
						hspace=0.1, height_ratios=[4, 1])

ax0 = fig.add_subplot(spec[0])
ax0.scatter(x,y, marker='.', label='\ntheta, 217 mdeg\n')
ax0.plot(eks,why,'k-', label='$m_1$: %0.3f\n $b_1$: %0.1f\n $m_2$: %0.3f\n $b_2$: %0.1f\n deltaH: %0.0f J/mol\n $T_M$: %0.1f K' % tuple(popt))
ax0.legend()
ax0.set_ylabel('ellipticity at 217nm, mdeg')
plt.tick_params('x', labelbottom=False)

ax1 = fig.add_subplot(spec[1])
ax1.scatter(x, residuals, marker='.')
ax1.set_ylabel('residuals')
ax1.set_xlabel('Temperature, Kelvin')

plt.suptitle('Brautigam Equation Curve Fit to PupB NTSD L74A Forward Melting Data')
plt.savefig(fn)
plt.show()

# %% [markdown]
# In the '.../intro_curve_fitting_python/thermal_denaturation_data' directory you will find the following files:

# %%
os.listdir(basedir+'/exponential_data/')
# Out:
# ['exponential2.csv', 'exponential3.csv', 'exponential1.csv']

# %% [markdown]
# It should not be too difficult to adapt your work from the above to treat these data sets.

# %% [markdown]
# ## Your work here:

# %% [markdown]
# [Solutions](./thermal_denaturation_solutions.ipynb)
